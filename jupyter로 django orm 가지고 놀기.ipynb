# %% [markdown]
# ### django 불러오기

# %%
import os, sys
# PWD = os.getenv('PWD')
PWD = os.path.abspath('.')

PROJ_MISSING_MSG = """Set an enviroment variable:\n
`DJANGO_PROJECT=your_project_name`\n
or call:\n
`init_django(your_project_name)`
"""

def init_django(project_name=None):
    os.chdir(PWD)
    project_name = project_name or os.environ.get('DJANGO_PROJECT') or None
    if project_name == None:
        raise Exception(PROJ_MISSING_MSG)
    sys.path.insert(0, os.getenv('PWD'))
    os.environ.setdefault('DJANGO_SETTINGS_MODULE', f'{project_name}.settings')
    os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
    import django
    django.setup()

# %%
PWD
# Out:
# 'c:\\Users\\user\\mydjango_project\\mydjango_board'

# %%
init_django('mydjango_board') #project name

# %% [markdown]
# ### model import

# %%
from board.models import Board, Comment

# %% [markdown]
# ### Insert or Update

# %%
board = Board(
    title="게시글1",
    content="내용1",
)

# %%
board
# Out:
# <Board: None - 게시글1>

# %%
board.save()

# %%
board
# Out:
# <Board: 20 - 게시글1>

# %% [markdown]
# -> 내용 확인

# %% [markdown]
# #### Manager 객체 - objects

# %%
Board.objects

# %%
board = Board.objects.create(
    title="게시글2",
    content="내용2"
)

# %%
board

# %%
board = Board.objects.create(
    title="게시글3",
    content="내용3"
)

# %%
data = []
board = Board(title="게시글1", content='내용')

for i in dir(board):
  print(i)
# Out:
# DoesNotExist
# MultipleObjectsReturned
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setstate__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# _check_column_name_clashes
# _check_constraints
# _check_default_pk
# _check_field_name_clashes
# _check_fields
# _check_id_field
# _check_index_together
# _check_indexes
# _check_local_fields
# _check_long_column_names
# _check_m2m_through_same_relationship
# _check_managers
# _check_model
# _check_model_name_db_lookup_clashes
# _check_ordering
# _check_property_name_related_field_accessor_clashes
# _check_single_primary_key
# _check_swappable
# _check_unique_together
# _do_insert
# _do_update
# _get_FIELD_display
# _get_expr_references
# _get_field_value_map
# _get_next_or_previous_by_FIELD
# _get_next_or_previous_in_order
# _get_pk_val
# _get_unique_checks
# _meta
# _perform_date_checks
# _perform_unique_checks
# _prepare_related_fields_for_save
# _save_parents
# _save_table
# _set_pk_val
# _state
# check
# clean
# clean_fields
# comment_set
# content
# created_at
# date_error_message
# delete
# from_db
# full_clean
# get_constraints
# get_deferred_fields
# get_next_by_created_at
# get_next_by_updated_at
# get_previous_by_created_at
# get_previous_by_updated_at
# id
# objects
# pk
# prepare_database_save
# refresh_from_db
# save
# save_base
# serializable_value
# title
# unique_error_message
# updated_at
# validate_constraints
# validate_unique

# %% [markdown]
# ### 여러 게시글을 한번에 insert하기

# %%
data = []
for i in range(10):
    board = Board(title=f"새로운 게시글{i}", content=f"여러게시글 insert {i}")
    data.append(board)

# %%
print(data)

# %%
Board.objects.bulk_create(data)

# %%
board = Board(title="게시물 추가", content="내용")
board

# %%
board.save()

# %% [markdown]
# # 조회하기

# %% [markdown]
# ## raw query로 조회하기

# %%
result = Board.objects.raw('SELECT * FROM board_board')
result

# %%
for i in result[:3]:
    print(i)
    print(i.id, i.title, i.content, i.created_at)

# %%
result[1].content

# %%
# Elastic Search

# 당근케이크

# [당근] =>  당근 케이크 레시피
#           당근케이크 만들기
#           당근 케이크 3분안에 만들기
# [케이크] => 당근 케이크 레시피
#           당근케이크 만들기
#           당근 케이크 3분안에 만들기
# [3분]    => 당근 케이크 3분안에 만들기

# %% [markdown]
# ## orm으로 조회하기

# %% [markdown]
# ### 전체 조회하기

# %%
board_list = Board.objects.all() # select * from board_board

# %%
board_list
# Out:
# <QuerySet [<Board: 1 - 게시글1>, <Board: 2 - 게시글2>, <Board: 3 - 수정>, <Board: 5 - 게시글1>, <Board: 6 - 게시글1>, <Board: 7 - 게시글2>, <Board: 8 - 게시글3>, <Board: 9 - 새로운 게시글0>, <Board: 10 - 새로운 게시글1>, <Board: 11 - 새로운 게시글2>, <Board: 12 - 새로운 게시글3>, <Board: 13 - 새로운 게시글4>, <Board: 14 - 새로운 게시글5>, <Board: 15 - 새로운 게시글6>, <Board: 16 - 새로운 게시글7>, <Board: 17 - 새로운 게시글8>, <Board: 18 - 새로운 게시글9>, <Board: 19 - 새로운 게시글>, <Board: 20 - 게시글1>, <Board: 21 - 게시글2>]>

# %%
print(board_list.query)

# %% [markdown]
# ### filter 걸어서 조회하기(where)

# %%
board_list = Board.objects.filter(title="게시글1")
board_list
# Out:
# <QuerySet [<Board: 1 - 게시글1>, <Board: 5 - 게시글1>, <Board: 6 - 게시글1>, <Board: 20 - 게시글1>]>

# %%
for board in board_list:
    print(board.id, board.title)

# %%
board_list = Board.objects.order_by('-created_at') # order by desc
board_list
# Out:
# <QuerySet [<Board: 21 - 게시글2>, <Board: 20 - 게시글1>, <Board: 19 - 새로운 게시글>, <Board: 16 - 새로운 게시글7>, <Board: 17 - 새로운 게시글8>, <Board: 18 - 새로운 게시글9>, <Board: 9 - 새로운 게시글0>, <Board: 10 - 새로운 게시글1>, <Board: 11 - 새로운 게시글2>, <Board: 12 - 새로운 게시글3>, <Board: 13 - 새로운 게시글4>, <Board: 14 - 새로운 게시글5>, <Board: 15 - 새로운 게시글6>, <Board: 8 - 게시글3>, <Board: 7 - 게시글2>, <Board: 6 - 게시글1>, <Board: 5 - 게시글1>, <Board: 3 - 수정>, <Board: 2 - 게시글2>, <Board: 1 - 게시글1>]>

# %%
board_list = Board.objects.order_by('-created_at')[2:4] # order by desc limit(2) offset(2)
board_list
# Out:
# <QuerySet [<Board: 19 - 새로운 게시글>, <Board: 16 - 새로운 게시글7>]>

# %% [markdown]
# ###  filter not 표시

# %%
board_list = Board.objects.exclude(title="게시글1")
board_list
# Out:
# <QuerySet [<Board: 2 - 게시글2>, <Board: 3 - 수정>, <Board: 7 - 게시글2>, <Board: 8 - 게시글3>, <Board: 9 - 새로운 게시글0>, <Board: 10 - 새로운 게시글1>, <Board: 11 - 새로운 게시글2>, <Board: 12 - 새로운 게시글3>, <Board: 13 - 새로운 게시글4>, <Board: 14 - 새로운 게시글5>, <Board: 15 - 새로운 게시글6>, <Board: 16 - 새로운 게시글7>, <Board: 17 - 새로운 게시글8>, <Board: 18 - 새로운 게시글9>, <Board: 19 - 새로운 게시글>, <Board: 21 - 게시글2>]>

# %%
from django.db.models import Q

# %% [markdown]
# 0001
# 1001

# %% [markdown]
# ->
# and: 0001
# or: 1001
# not 0001 => 1110
# xor: 1000

# %% [markdown]
# ####  비트연산
# - ~: not
# - &: and
# - |: or
# - ^: xor

# %%
board_list = Board.objects.filter(~Q(title="게시글1"))
board_list
# Out:
# <QuerySet [<Board: 2 - 게시글2>, <Board: 3 - 수정>, <Board: 7 - 게시글2>, <Board: 8 - 게시글3>, <Board: 9 - 새로운 게시글0>, <Board: 10 - 새로운 게시글1>, <Board: 11 - 새로운 게시글2>, <Board: 12 - 새로운 게시글3>, <Board: 13 - 새로운 게시글4>, <Board: 14 - 새로운 게시글5>, <Board: 15 - 새로운 게시글6>, <Board: 16 - 새로운 게시글7>, <Board: 17 - 새로운 게시글8>, <Board: 18 - 새로운 게시글9>, <Board: 19 - 새로운 게시글>, <Board: 21 - 게시글2>]>

# %% [markdown]
# ## 조회하기 고급

# %% [markdown]
# ### 다양한 조건

# %% [markdown]
# #### or

# %%
board_list = Board.objects.filter(Q(title="게시글1") | Q(title="게시글2"))
board_list
# Out:
# <QuerySet [<Board: 1 - 게시글1>, <Board: 2 - 게시글2>, <Board: 5 - 게시글1>, <Board: 6 - 게시글1>, <Board: 7 - 게시글2>, <Board: 20 - 게시글1>, <Board: 21 - 게시글2>]>

# %% [markdown]
# ##### and 와 연산자

# %% [markdown]
# - gte: greater than equal
# - lte: less than equal
# - lt: less than
# - gt: greater than

# %%
board_list = Board.objects.filter(Q(id__gte=10))
board_list
# Out:
# <QuerySet [<Board: 10 - 새로운 게시글1>, <Board: 11 - 새로운 게시글2>, <Board: 12 - 새로운 게시글3>, <Board: 13 - 새로운 게시글4>, <Board: 14 - 새로운 게시글5>, <Board: 15 - 새로운 게시글6>, <Board: 16 - 새로운 게시글7>, <Board: 17 - 새로운 게시글8>, <Board: 18 - 새로운 게시글9>, <Board: 19 - 새로운 게시글>, <Board: 20 - 게시글1>, <Board: 21 - 게시글2>]>

# %%
board_list = Board.objects.filter(Q(title__startswith="게시") & Q(created_at__year=2023))
board_list
# Out:
# <QuerySet [<Board: 1 - 게시글1>, <Board: 2 - 게시글2>, <Board: 5 - 게시글1>, <Board: 6 - 게시글1>, <Board: 7 - 게시글2>, <Board: 8 - 게시글3>, <Board: 20 - 게시글1>, <Board: 21 - 게시글2>]>

# %% [markdown]
# # 관계 추가하기

# %% [markdown]
# 1번 댓글에 댓글을 3가지 이상 입력하세요

# %%
comment = Comment(
    board_id = 1,
    content = "댓글 내용2"
)
comment.save()

# %%
board = Board.objects.get(id=1)
board
# Out:
# <Board: 1 - 게시글1>

# %%
comment = Comment.objects.create(
  board= board,
  content="댓글 내용3"
)

# %%
board = Board.objects.get(id=1)
comment = Comment.objects.create(
    board=board,
    content = "댓글 내용3"
)

# %%
comment

# %%
for i in range(10):
    Comment.objects.create(
        board = Board.objects.get(id=2),
        content = f"댓글{i}"
    )

# %% [markdown]
# ## 관계 조회하기

# %%
Comment.objects.all()
# Out:
# <QuerySet [<Comment: Comment object (1)>, <Comment: Comment object (2)>, <Comment: Comment object (3)>, <Comment: Comment object (4)>, <Comment: Comment object (5)>, <Comment: Comment object (6)>, <Comment: Comment object (7)>, <Comment: Comment object (8)>, <Comment: Comment object (9)>, <Comment: Comment object (10)>, <Comment: Comment object (11)>, <Comment: Comment object (12)>, <Comment: Comment object (13)>, <Comment: Comment object (14)>, <Comment: Comment object (15)>]>

# %%
comment_list = Comment.objects.all()
comment_list
# Out:
# <QuerySet [<Comment: Comment object (1)>, <Comment: Comment object (2)>, <Comment: Comment object (3)>, <Comment: Comment object (4)>, <Comment: Comment object (5)>, <Comment: Comment object (6)>, <Comment: Comment object (7)>, <Comment: Comment object (8)>, <Comment: Comment object (9)>, <Comment: Comment object (10)>, <Comment: Comment object (11)>, <Comment: Comment object (12)>, <Comment: Comment object (13)>, <Comment: Comment object (14)>, <Comment: Comment object (15)>]>

# %%
comment = comment_list[0]
comment
# Out:
# <Comment: Comment object (1)>

# %%
comment.id, comment.content, comment.board, comment.board_id
# Out:
# (1, '댓글 내용2', <Board: 1 - 게시글1>, 1)

# %%
board = comment.board
board.comment_set.all()
# Out:
# <Board: 1 - 게시글1>

# %%
class Car:
  car_no = 0

  def __init__(self, name, cc):
    self.name = name
    self.cc = cc
    self.speed = 0

  def accelate(self):
    self.speed += 1

car1 = Car(name="bmw", cc=2000)

Car.car_no
car1.speed
car1.accelate()
car1.speed

Car.speed

# %%
board_list = Board.objects.filter(id__lte=3)
board_list

# %%
board = board_list[0]
board

# %% [markdown]
# ###  board가 가지고 있는 comment 모두 조회

# %%
# 1번 게시글과 관계를 맺고 있는 모든 댓글데이터 가져오기
# 조인

# %%
board = Board.objects.get(id=2)
board

# %%
board.comment_set.all()

# %%
board_list = Board.objects.all()
for board in board_list:
    print(board)
    print(board.comment_set.all())
    print('-'*10)

# %%
board_list = Board.objects.filter(id__lte=5).prefetch_related('comment_set')
board_list

# %%
comment_list = board_list[0].comment_set.all()
comment_list

# %%
comment = comment_list[0]
comment.board

# %% [markdown]
# # transaction

# %%
from django.db import transaction

# %%
@transaction.atomic
def sample():
    board = Board.objects.create(
        title='게시글',
        content = "atomic 게시글"
    )
    Comment.objects.create(
        board=board,
        content="atomic 댓글"
    )

# %%
sample()

# %%
with transaction.atomic():
    board = Board.objects.create(
        title='게시글',
        content = "atomic 게시글"
    )
    Comment.objects.create(
        board=board,
        content="atomic 댓글"
    )

# %% [markdown]
# ### with 절에대해서

# %%
file = open("sample.txt", 'wt')
file.write("파일 쓰기")
file.close()

# %%
with open("sample.txt", 'wt') as f:
    f.write("파일 쓰기")

# %% [markdown]
# ### decorator - @ = 함수다

# %%
def new_decorator(func):
    def wrap():
        print("decorator 시작")
        func()
        print("decorator 종료")
    return wrap

# %%
def myfunc2():
  print('함수 실행!')
wrap = new_decorator(myfunc2)
wrap()

# %%
@new_decorator
def my_func():
    print('my_func')
my_func()
# Out:
# decorator 시작
# my_func
# decorator 종료

# %%
def my_func2():
    print('my_func')

# %%
new_decorator(my_func2)()
